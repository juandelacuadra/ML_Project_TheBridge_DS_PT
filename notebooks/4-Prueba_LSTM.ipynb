# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_base = pd.read_csv('../data/processed/data_processed_1990_2023.csv', index_col='fecha')
df_base.drop('target', axis=1, inplace=True)
df_base.index = pd.to_datetime(df_base.index)
df_base.tail(7)
# Out:
#             tmin  tmax  tmed  presMin  presMax   dir  velmedia  racha   sol  \
# fecha
# 2023-03-02   0.5  16.9   8.7   1014.4   1017.7  30.0       1.1    5.8  11.0
# 2023-03-03   0.1  18.5   9.3   1013.9   1018.1   5.0       1.4    5.8  10.8
# 2023-03-04   6.8  17.9  12.4   1014.5   1017.6  99.0       1.9    5.0   5.2
# 2023-03-05   6.0  15.5  10.8   1011.0   1015.3  99.0       0.6    5.0   0.0
# 2023-03-06  10.3  15.9  13.1   1008.7   1013.4  21.0       1.9    8.3   0.0
# 2023-03-07  12.9  19.7  16.3   1009.8   1013.4  22.0       3.9   10.3   3.2
# 2023-03-08  14.4  20.5  17.4   1011.6   1015.1  22.0       6.1   10.3   3.2
#
#             prec
# fecha
# 2023-03-02   0.0
# 2023-03-03   0.0
# 2023-03-04   0.0
# 2023-03-05   1.5
# 2023-03-06   3.3
# 2023-03-07   0.6
# 2023-03-08   2.5

# %%
df_last_500 = df_base.iloc[-500:]
df_last_500.head()
# Out:
#             tmin  tmax  tmed  presMin  presMax   dir  velmedia  racha   sol  \
# fecha
# 2021-10-25  11.2  26.6  18.9   1013.7   1018.0  99.0       1.9    6.1   8.9
# 2021-10-26  12.6  26.6  19.6   1014.2   1017.2   8.0       2.8    9.2   8.2
# 2021-10-27  12.5  26.3  19.4   1013.8   1017.7   6.0       4.2   10.8  10.2
# 2021-10-28  12.5  25.9  19.2   1010.8   1015.1  21.0       2.2    7.8   9.8
# 2021-10-29  16.4  23.6  20.0   1009.2   1013.1  22.0       7.2   15.3   1.1
#
#             prec
# fecha
# 2021-10-25   0.0
# 2021-10-26   0.0
# 2021-10-27   0.0
# 2021-10-28   0.0
# 2021-10-29   1.5
